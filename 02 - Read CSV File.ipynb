# %%
# df = spark.read.format(file_type)\
#     .option(csv,parquet,orc,json,avro)
#     .option("inferSchema")
#     .option("header",)
#     .option("sep",)
#     .schema(schema_df)
#     .load(file_location)

# %%
df = spark.read.format("csv").option("inferSchema",True).option("header",True).option("sep",",").load("/FileStore/tables/imdb_top_1000.csv")
display(df)
print(df.count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.read.format("csv").options(inferSchema=True,header=True,sep=",").load("/FileStore/tables/imdb_top_1000.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Series_Title: string (nullable = true)
#  |-- Released_Year: string (nullable = true)
#  |-- Runtime: integer (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- IMDB_Rating: double (nullable = true)
#  |-- Director: string (nullable = true)
#  |-- Star1: string (nullable = true)
#  |-- No_of_Votes: integer (nullable = true)
#  |-- Gross: double (nullable = true)
#  |-- Metascore: double (nullable = true)

# %%
# reading mutiple files
dataframe1=spark.read.format('csv').options(header="True",sep=",",inferSchema=True).load(["dbfs:/FileStore/tables/car_data.csv","dbfs:/FileStore/tables/insurance.csv"])
display(dataframe1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dataframe1.printSchema()
# Out:
# root
#  |-- age: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- bmi: string (nullable = true)
#  |-- children: string (nullable = true)
#  |-- smoker: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- charges: string (nullable = true)

# %%
data=spark.read.format('csv').options(header="True",sep=",").load("dbfs:/FileStore/tables/")

# %%
#create own schema
from pyspark.sql.types import *


schema_defined=StructType([StructField('Year',IntegerType(),True),
                           StructField('Name',StringType(),True),
                           StructField('country',StringType(),True)])

# %%
schema = StructType([StructField('Series_Title',StringType(),True),
                    StructField('Released_Year',IntegerType(),True),
                    StructField('Runtime',IntegerType(),True),
                    StructField('Genre',StringType(),True),
                    StructField('IMDB_Rating',StringType(),True),
                    StructField('Director',StringType(),True),
                    StructField('Star1',StringType(),True),
                    StructField('No_of_Votes',IntegerType(),True),
                    StructField('Gross',StringType(),True),
                    StructField('Metascore',StringType(),True)])

# %%
print(schema)
# Out:
# StructType([StructField('Series_Title', StringType(), True), StructField('Released_Year', IntegerType(), True), StructField('Runtime', IntegerType(), True), StructField('Genre', StringType(), True), StructField('IMDB_Rating', StringType(), True), StructField('Director', StringType(), True), StructField('Star1', StringType(), True), StructField('No_of_Votes', IntegerType(), True), StructField('Gross', StringType(), True), StructField('Metascore', StringType(), True)])

# %%
df.show()
# Out:
# +--------------------+-------------+-------+---------+-----------+--------------------+------------------+-----------+------------+---------+
# |        Series_Title|Released_Year|Runtime|    Genre|IMDB_Rating|            Director|             Star1|No_of_Votes|       Gross|Metascore|
# +--------------------+-------------+-------+---------+-----------+--------------------+------------------+-----------+------------+---------+
# |The Shawshank Red...|         1994|    142|    Drama|        9.3|      Frank Darabont|       Tim Robbins|    2343110| 2.8341469E7|     80.0|
# |       The Godfather|         1972|    175|    Crime|        9.2|Francis Ford Coppola|     Marlon Brando|    1620367|1.34966411E8|    100.0|
# |     The Dark Knight|         2008|    152|   Action|        9.0|   Christopher Nolan|    Christian Bale|    2303232|5.34858444E8|     84.0|
# ...

# %%
movie_schema = StructType([
    StructField('Name', StringType(), True),
    StructField('Released_Year', IntegerType(), True),
    StructField('Runtime', IntegerType(), True),
    StructField('Genre', StringType(), True),
    StructField('IMDB_Rating', DoubleType(), True),
    StructField('Director', StringType(), True),
    StructField('Star1', StringType(), True),
    StructField('No_of_Votes', IntegerType(), True),
    StructField('Gross', IntegerType(), True),
    StructField('Metascore', IntegerType(), True),
])

# %%
df = spark.read.format("csv").schema(movie_schema).option("header",True).option("sep",",").load("/FileStore/tables/imdb_top_1000.csv")

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Released_Year: integer (nullable = true)
#  |-- Runtime: integer (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- IMDB_Rating: double (nullable = true)
#  |-- Director: string (nullable = true)
#  |-- Star1: string (nullable = true)
#  |-- No_of_Votes: integer (nullable = true)
#  |-- Gross: integer (nullable = true)
#  |-- Metascore: integer (nullable = true)

# %%
movie_schema="Name STRING, Released_Year INT, Runtime INT, Genre STRING, IMDB_Rating DOUBLE, Director STRING, Star1 STRING, No_of_Votes INT, Gross INT, Metascore INT"

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Released_Year: integer (nullable = true)
#  |-- Runtime: integer (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- IMDB_Rating: double (nullable = true)
#  |-- Director: string (nullable = true)
#  |-- Star1: string (nullable = true)
#  |-- No_of_Votes: integer (nullable = true)
#  |-- Gross: integer (nullable = true)
#  |-- Metascore: integer (nullable = true)
