# %%
sc.defaultParallelism
# Out:
# Out[2]: 8

# %%
spark.conf.get("spark.sql.files.maxPartitionBytes")
# Out:
# Out[3]: '134217728b'

# %%
from pyspark.sql.types import *

# %%
df = spark.createDataFrame(range(10) , IntegerType())
display(df)
df.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>0</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>6</td></tr><tr><td>7</td></tr><tr><td>8</td></tr><tr><td>9</td></tr></tbody></table></div>
# Out[5]: 8

# %%
df.rdd.glom().collect()
# Out:
# Out[6]: [[Row(value=0)],
#  [Row(value=1)],
#  [Row(value=2)],
#  [Row(value=3), Row(value=4)],
#  [Row(value=5)],
#  [Row(value=6)],
#  [Row(value=7)],
#  [Row(value=8), Row(value=9)]]

# %%
dbutils.fs.ls("/FileStore/tables/imdb_top_1000.csv")
# Out:
# Out[7]: [FileInfo(path='dbfs:/FileStore/tables/imdb_top_1000.csv', name='imdb_top_1000.csv', size=87267, modificationTime=1679455707000)]

# %%
df1 = spark.read.format("csv").option("inferSchema",True).option("header",True).option("sep",",").load("/FileStore/tables/imdb_top_1000.csv")
df1.rdd.getNumPartitions()
# Out:
# Out[8]: 1

# %%
spark.conf.set("spark.sql.files.maxPartitionBytes", 2000)
spark.conf.get("spark.sql.files.maxPartitionBytes")
# Out:
# Out[9]: '2000'

# %%
1000 mb --> spark.conf.set("spark.sql.files.maxPartitionBytes", 125mb) --> 8
1000 mb ---> df.repatition(8)

# %%
df = spark.createDataFrame(range(10) , IntegerType())

df.rdd.getNumPartitions()
# Out:
# Out[10]: 8

# %%
df1 = df.repartition(20)

df1.rdd.getNumPartitions()
# Out:
# Out[11]: 20

# %%
df1.rdd.glom().collect()
# Out:
# Out[11]: [[],
#  [Row(value=0)],
#  [],
#  [Row(value=5)],
#  [],
#  [],
#  [Row(value=1)],
#  [],
#  [Row(value=6)],
#  [Row(value=2)],
#  [],
#  [],
#  [Row(value=7)],
#  [],
#  [],
#  [Row(value=3)],
#  [Row(value=4)],
#  [Row(value=8)],
#  [Row(value=9)],
#  []]

# %%
df1 = df.repartition(2)

df1.rdd.getNumPartitions()
# Out:
# Out[12]: 2

# %%
df1.rdd.glom().collect()
# Out:
# Out[14]: [[Row(value=0),
#   Row(value=1),
#   Row(value=2),
#   Row(value=3),
#   Row(value=5),
#   Row(value=6),
#   Row(value=7),
#   Row(value=8)],
#  [Row(value=4), Row(value=9)]]

# %%
df2 = df.coalesce()

df2.rdd.getNumPartitions()

df2.rdd.glom().collect()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-2971415076626222> in <cell line: 1>()
# ----> 1 df2 = df.coalesce()
#       2
#       3 df2.rdd.getNumPartitions()
#       4
#       5 df2.rdd.glom().collect()
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# TypeError: coalesce() missing 1 required positional argument: 'numPartitions'

# %%
data = [("john",34,"male"),("mike",22,"male"),("neha",34,"female")]

coulmn = ["name","age","gender"]


df = spark.createDataFrame(data , coulmn)

# %%
repartioned_df = df.write.partitionBy("gender")

# %%
repartioned= df.repartition("gender","age")

# %%
repartioned.show()
# Out:
# +----+---+------+
# |name|age|gender|
# +----+---+------+
# |john| 34|  male|
# |mike| 22|  male|
# |neha| 34|female|
# +----+---+------+

# %%
repartioned.drop()
# Out:
# Out[29]: DataFrame[name: string, age: bigint, gender: string]
